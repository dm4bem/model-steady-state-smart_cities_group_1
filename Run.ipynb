# %%
# %run Steady_state_and_step_response.py
# Out:
# ---Steady state---
# inside Temperature(steady state): 18.56 °C
# Temperature in nodes(DAE, θss):
# [-6.27  4.56 15.39 15.91 16.44  5.57 18.56  3.32]
# Thermal load controller: q= 1444.0 W
# Thermal loads: q= [ -699.  -329.  -329.  -329.  -329.   487.  -763.  -935. -1692. -1422.
#   -115.  1444.] W
# ---Step response---
# dtmax = 49 s
# dt = 40 s
# t_settle = 337101 s = 93.6 h
# duration = 338400 s = 94.0 h
